# %% [markdown]
# # **Colab-Stable-diffusion-webui-FAS-disk**
#
# > 如有错误,请在[抱脸](https://huggingface.co/datasets/FASOXO/FAS-warehouse)上提供的Q群号反馈错误内容
#
# > 作者：**法斯** **FAS**
#
# > **倒卖者全家死光**
#
# >版本: 1.3
#
# > 相关链接 / [Civitai](https://civitai.com/) / [huggingface](https://huggingface.co/) / [ngrok](https://ngrok.com/) /

# %%
# @title **基本设置**
# %%capture
# !wget https://huggingface.co/datasets/FASOXO/FAS_Colab_Stable_diffusion/resolve/main/FASSD.zip
# !unzip FASSD.zip

# %cd /content
Stable_diffusion_version = "automatic1111_new"  #@param ["Camenduru_new", "automatic1111_new", "Camenduru_2_3","automatic1111_2_3" ]
#@markdown   > Stable diffusion版本
Advanced_plugin = True #@param {type:"boolean"}
#@markdown   > 进阶插件
sd_ui = "Catppuccin" #@param ["lobe_sd_ui", "Catppuccin", "kitchen"]
#@markdown   > 选择UI
#@markdown ---
plugins = "" #@param {type:"string"}
scripts = "" #@param {type:"string"}
#@markdown   >注：scripts类脚本/plugins插添加处 | 请将wedui改成{FAS}否则提示警告无法运行导致封号,每个链接请用英文逗号隔开,必须是github的链接
controlnet = False #@param {type:"boolean"}
#@markdown   > controlnet模型获取
#@markdown ---
google_drive = False #@param {type:"boolean"}
if google_drive :
  from google.colab import drive
  drive.mount('/content/drive')
#@markdown   > 链接谷歌网盘
#@markdown ---
initial_model_name = "OA1pastelmix.safetensors" #@param {type:"string"}
#@markdown   > 初始模型名字
Initial_model_link = "https://civitai.com/api/download/models/39775" #@param {type:"string"}
#@markdown   > 初始模型链接

# %cd /content/ipynbFASSD
# %run SDyilai.ipynb

# %%
#@title **额外选项**
# %%capture
# %cd /content

#@markdown > **+- 模型 -+**

Counterfeit3 = False #@param {type:"boolean"}

CuteYukiMix3 = False #@param {type:"boolean"}

QteaMix通用Q版模型 = False #@param {type:"boolean"}

天空之境 = False #@param {type:"boolean"}

Anything_V5 = False #@param {type:"boolean"}

AICE冰可 = False #@param {type:"boolean"}

TMND_Mix = False #@param {type:"boolean"}

GhostMix3 = False #@param {type:"boolean"}

AbyssOrangeMix3 = False #@param {type:"boolean"}

PastelMix = False #@param {type:"boolean"}

SDXL1 = False #@param {type:"boolean"}

#@markdown > **+- VAE -+**

vae_ft_mse_840000_ema_pruned = False #@param {type:"boolean"}

Coun2_5vae = False #@param {type:"boolean"}

clearvae = False #@param {type:"boolean"}

clearvae_main = False #@param {type:"boolean"}

kl_f8_anime2 = False #@param {type:"boolean"}

orangemix = False #@param {type:"boolean"}

pastelvae = False #@param {type:"boolean"}

#@markdown > **+- Lora -+**

genshin_impact = False #@param {type:"boolean"}

blue_archive = False #@param {type:"boolean"}

Honkai_impact = False #@param {type:"boolean"}

arknights = False #@param {type:"boolean"}

风格Lora = False #@param {type:"boolean"}

#@markdown > **+- embeddings -+**

fas_233embeddings = True #@param {type:"boolean"}

#@markdown 233个embeddings文件 by FAS

# %cd /content/ipynbFASSD
# %run SDxiazai.ipynb

# %%
#@title **下载文件**
# %cd /content/stable-diffusion-{FAS}
#请按照格式要求更换
#模型下载格式#!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/编号 -d /content/stable-diffusion-{FAS}/models/Stable-diffusion -o 名字.safetensors
#Lora格式：!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/url编号 -d /content/stable-diffusion-{FAS}/models/Lora -o 名字.safetensors
#vae格式：!aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://civitai.com/api/download/models/url编号 -d /content/stable-diffusion-{FAS}/models/VAE -o 名字.vae.pt

# %%
#@title **启动**
startup_item = "" #@param {type:"string"}
#@markdown > 自己添加启动项
ngrok_token = "2SMYrXDVntMiJrfyBsWLynrqGud_7ecBztPNYQhe1PXSxvcGo" #@param {type:"string"}
#@markdown > Ngorktoken 以启动Ngork内网穿透服务 （如果无就乱填）[申请token网址](https://dashboard.ngrok.com/)
xformers = True #@param {type:"boolean"}
#@markdown > 启动网络优化（推荐）
lowram = False #@param {type:"boolean"}
#@markdown > 低配置运行
gradio_queue = True #@param {type:"boolean"}
#@markdown > 实验选项:中断重启UI按钮 （推荐）
enable_insecure_extension_access = True #@param {type:"boolean"}
#@markdown > 启用扩展选项卡，无论其他选项如何 (推荐)
no_half = False #@param {type:"boolean"}
#@markdown > 模型全精度 半精度（关是半精度)
no_half_vae = False #@param {type:"boolean"}
#@markdown > VAE全精度 半精度（关是半精度)
multiple = False #@param {type:"boolean"}
#@markdown > 多内网穿透（需内网穿透插件）
api = True #@param {type:"boolean"}
#@markdown > 可以进行api调用

# %cd /content/ipynbFASSD
# %run SDqidon.ipynb

# %%
#@title **将所有图片变为压缩包**
# !zip -r /content/图片.zip /content/stable-diffusion-{FAS}/outputs
#@markdown > 保存位置/content

# %%
#@title **将图片保存谷歌网盘**
# %cd /content/stable-diffusion-{FAS}/outputs
# !zip -r /content/drive/MyDrive/images.zip txt2img-images

# %% [markdown]
# # 你们的赞助是对作者最大的动力！！！
#
# ![image.png](data:image/png;base64,...)
